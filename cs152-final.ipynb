# %%
X = """
[req('1a',anj,anj1,3)-[_A,_B,_C],req('1a',atvz,atvz1,3)-[_D,_E,_F],req('1a',bio,bio1,2)-[_G,_H],req('1a',fiz,fiz1,2)-[_I,_J],req('1a',geo,geo1,2)-[_K,_L],req('1a',kem,kem1,2)-[_M,_N],req('1a',mat,mat1,5)-[_O,_P,_Q,_R,_S],req('1a',nej,nej1,3)-[_T,_U,_V],req('1a',rai,rai1,2)-[_W,_X],req('1a',sjk,sjk1,4)-[_Y,_Z,_A1,_B1],req('1a',ume,ume1,2)-[_C1,_D1],req('1a',zgo,zgo1,2)-[_E1,_F1],req('1b',anj,anj2,3)-[_G1,_H1,_I1],req('1b',atvz,atvz2,3)-[_J1,_K1,_L1],req('1b',bio,bio1,2)-[_M1,_N1],req('1b',fiz,fiz2,2)-[_O1,_P1],req('1b',geo,geo1,2)-[_Q1,_R1],req('1b',kem,kem2,2)-[_S1,_4479],req('1b',mat,mat2,5)-[_4496,_4498,_4500,_4502,_4504],req('1b',nej,nej2,3)-[_4521,_4523,_4525],req('1b',rai,rai1,2)-[_4542,_4544],req('1b',sjk,sjk1,4)-[_4561,_4563,_4565,_4567],req('1b',ume,ume1,2)-[_4584,_4586],req('1b',zgo,zgo2,2)-[_4603,_4605],req('1c',anj,anj3,3)-[_4622,_4624,_4626],req('1c',atvz,atvz1,3)-[_4643,_4645,_4647],req('1c',bio,bio1,2)-[_4664,_4666],req('1c',fiz,fiz1,2)-[_4683,_4685],req('1c',geo,geo1,2)-[_4702,_4704],req('1c',kem,kem1,2)-[_4721,_4723],req('1c',mat,mat3,5)-[_4740,_4742,_4744,_4746,_4748],req('1c',nej,nej1,3)-[_4765,_4767,_4769],req('1c',rai,rai1,2)-[_4786,_4788],req('1c',sjk,sjk2,4)-[_4805,_4807,_4809,_4811],req('1c',ume,ume1,2)-[_4828,_4830],req('1c',zgo,zgo1,2)-[_4847,_4849],req('1d',anj,anj3,3)-[_4866,_4868,_4870],req('1d',atvz,atvz2,3)-[_4887,_4889,_4891],req('1d',bio,bio1,2)-[_4908,_4910],req('1d',fiz,fiz2,2)-[_4927,_4929],req('1d',geo,geo1,2)-[_4946,_4948],req('1d',kem,kem2,2)-[_4965,_4967],req('1d',mat,mat4,5)-[_4984,_4986,_4988,_4990,_4992],req('1d',nej,nej2,3)-[_5009,_5011,_5013],req('1d',rai,rai1,2)-[_5030,_5032],req('1d',sjk,sjk3,4)-[_5049,_5051,_5053,_5055],req('1d',ume,ume1,2)-[_5072,_5074],req('1d',zgo,zgo2,2)-[_5091,_5093],req('2a',anj,anj1,3)-[_5110,_5112,_5114],req('2a',atvz,atvz2,3)-[_5131,_5133,_5135],req('2a',bio,bio1,2)-[_5152,_5154],req('2a',fiz,fiz2,3)-[_5171,_5173,_5175],req('2a',geo,geo1,2)-[_5192,_5194],req('2a',kem,kem2,2)-[_5211,_5213],req('2a',mat,mat2,5)-[_5230,_5232,_5234,_5236,_5238],req('2a',nej,nej2,3)-[_5255,_5257,_5259],req('2a',psi,psi1,2)-[_5276,_5278],req('2a',sjk,sjk1,4)-[_5295,_5297,_5299,_5301],req('2a',zgo,zgo2,2)-[_5318,_5320],req('2b',anj,anj2,3)-[_5337,_5339,_5341],req('2b',atvz,atvz1,3)-[_5358,_5360,_5362],req('2b',bio,bio1,2)-[_5379,_5381],req('2b',fiz,fiz1,2)-[_5398,_5400],req('2b',geo,geo1,2)-[_5417,_5419],req('2b',kem,kem1,2)-[_5436,_5438],req('2b',mat,mat3,5)-[_5455,_5457,_5459,_5461,_5463],req('2b',nej,nej1,3)-[_5480,_5482,_5484],req('2b',psi,psi1,2)-[_5501,_5503],req('2b',sjk,sjk2,4)-[_5520,_5522,_5524,_5526],req('2b',zgo,zgo1,2)-[_5543,_5545],req('2c',anj,anj2,3)-[_5562,_5564,_5566],req('2c',atvz,atvz2,3)-[_5583,_5585,_5587],req('2c',bio,bio1,2)-[_5604,_5606],req('2c',fiz,fiz2,2)-[_5623,_5625],req('2c',geo,geo1,2)-[_5642,_5644],req('2c',kem,kem2,2)-[_5661,_5663],req('2c',mat,mat4,5)-[_5680,_5682,_5684,_5686,_5688],req('2c',nej,nej2,3)-[_5705,_5707,_5709],req('2c',psi,psi1,2)-[_5726,_5728],req('2c',sjk,sjk2,4)-[_5745,_5747,_5749,_5751],req('2c',zgo,zgo2,2)-[_5768,_5770],req('2d',anj,anj3,3)-[_5787,_5789,_5791],req('2d',atvz,atvz1,3)-[_5808,_5810,_5812],req('2d',bio,bio1,2)-[_5829,_5831],req('2d',fiz,fiz1,3)-[_5848,_5850,_5852],req('2d',geo,geo1,2)-[_5869,_5871],req('2d',kem,kem1,2)-[_5888,_5890],req('2d',mat,mat1,5)-[_5907,_5909,_5911,_5913,_5915],req('2d',nej,nej1,3)-[_5932,_5934,_5936],req('2d',psi,psi1,2)-[_5953,_5955],req('2d',sjk,sjk3,4)-[_5972,_5974,_5976,_5978],req('2d',zgo,zgo1,2)-[_5995,_5997],req('3a',anj,anj1,3)-[_6014,_6016,_6018],req('3a',atvz,atvz1,3)-[_6035,_6037,_6039],req('3a',bio,bio1,2)-[_6056,_6058],req('3a',fiz,fiz1,2)-[_6075,_6077],req('3a',geo,geo1,2)-[_6094,_6096],req('3a',kem,kem1,2)-[_6113,_6115],req('3a',mat,mat3,4)-[_6132,_6134,_6136,_6138],req('3a',nej,nej1,3)-[_6155,_6157,_6159],req('3a',sjk,sjk1,4)-[_6176,_6178,_6180,_6182],req('3a',soc,soc1,2)-[_6199,_6201],req('3a',zgo,zgo1,2)-[_6218,_6220],req('3b',anj,anj1,3)-[_6237,_6239,_6241],req('3b',atvz,atvz2,3)-[_6258,_6260,_6262],req('3b',bio,bio1,2)-[_6279,_6281],req('3b',fiz,fiz2,2)-[_6298,_6300],req('3b',geo,geo1,2)-[_6317,_6319],req('3b',kem,kem2,2)-[_6336,_6338],req('3b',mat,mat4,4)-[_6355,_6357,_6359,_6361],req('3b',nej,nej2,3)-[_6378,_6380,_6382],req('3b',sjk,sjk2,4)-[_6399,_6401,_6403,_6405],req('3b',soc,soc1,2)-[_6422,_6424],req('3b',zgo,zgo2,2)-[_6441,_6443],req('3c',anj,anj2,3)-[_6460,_6462,_6464],req('3c',atvz,atvz1,3)-[_6481,_6483,_6485],req('3c',bio,bio1,1)-[_6502],req('3c',fiz,fiz1,2)-[_6519,_6521],req('3c',geo,geo1,2)-[_6538,_6540],req('3c',kem,kem1,2)-[_6557,_6559],req('3c',mat,mat1,4)-[_6576,_6578,_6580,_6582],req('3c',nej,nej1,3)-[_6599,_6601,_6603],req('3c',sjk,sjk3,4)-[_6620,_6622,_6624,_6626],req('3c',soc,soc1,2)-[_6643,_6645],req('3c',zgo,zgo1,2)-[_6662,_6664],req('3d',anj,anj3,3)-[_6681,_6683,_6685],req('3d',atvz,atvz2,3)-[_6702,_6704,_6706],req('3d',bio,bio1,1)-[_6723],req('3d',fiz,fiz2,2)-[_6740,_6742],req('3d',geo,geo1,2)-[_6759,_6761],req('3d',kem,kem2,2)-[_6778,_6780],req('3d',mat,mat2,4)-[_6797,_6799,_6801,_6803],req('3d',nej,nej2,3)-[_6820,_6822,_6824],req('3d',sjk,sjk1,4)-[_6841,_6843,_6845,_6847],req('3d',soc,soc1,2)-[_6864,_6866],req('3d',zgo,zgo2,2)-[_6883,_6885],req('4a',anj,anj1,4)-[_6902,_6904,_6906,_6908],req('4a',atvz,atvz2,3)-[_6925,_6927,_6929],req('4a',fil,fil1,2)-[_6946,_6948],req('4a',mat,mat4,5)-[_6965,_6967,_6969,_6971,_6973],req('4a',nej,nej2,2)-[_6990,_6992],req('4a',sjk,sjk1,5)-[_7009,_7011,_7013,_7015,_7017],req('4a',zgo,zgo1,2)-[_7034,_7036],req('4b',anj,anj2,4)-[_7053,_7055,_7057,_7059],req('4b',atvz,atvz1,3)-[_7076,_7078,_7080],req('4b',fil,fil1,2)-[_7097,_7099],req('4b',mat,mat1,5)-[_7116,_7118,_7120,_7122,_7124],req('4b',nej,nej1,2)-[_7141,_7143],req('4b',sjk,sjk2,5)-[_7160,_7162,_7164,_7166,_7168],req('4b',zgo,zgo1,2)-[_7185,_7187],req('4c',anj,anj1,4)-[_7204,_7206,_7208,_7210],req('4c',atvz,atvz2,3)-[_7227,_7229,_7231],req('4c',fil,fil1,2)-[_7248,_7250],req('4c',mat,mat2,5)-[_7267,_7269,_7271,_7273,_7275],req('4c',nej,nej2,2)-[_7292,_7294],req('4c',sjk,sjk3,5)-[_7311,_7313,_7315,_7317,_7319],req('4c',zgo,zgo1,2)-[_7336,_7338],req('4d',anj,anj2,4)-[_7355,_7357,_7359,_7361],req('4d',atvz,atvz1,3)-[_7378,_7380,_7382],req('4d',fil,fil1,2)-[_7399,_7401],req('4d',mat,mat3,5)-[_7418,_7420,_7422,_7424,_7426],req('4d',nej,nej1,2)-[_7443,_7445],req('4d',sjk,sjk3,5)-[_7462,_7464,_7466,_7468,_7470],req('4d',zgo,zgo1,2)-[_7487,_7489]]
"""

# %%
X.split("],")
# Out:
# ["\n[req('1a',anj,anj1,3)-[_A,_B,_C",
#  "req('1a',atvz,atvz1,3)-[_D,_E,_F",
#  "req('1a',bio,bio1,2)-[_G,_H",
#  "req('1a',fiz,fiz1,2)-[_I,_J",
#  "req('1a',geo,geo1,2)-[_K,_L",
#  "req('1a',kem,kem1,2)-[_M,_N",
#  "req('1a',mat,mat1,5)-[_O,_P,_Q,_R,_S",
#  "req('1a',nej,nej1,3)-[_T,_U,_V",
#  "req('1a',rai,rai1,2)-[_W,_X",
#  "req('1a',sjk,sjk1,4)-[_Y,_Z,_A1,_B1",
#  "req('1a',ume,ume1,2)-[_C1,_D1",
#  "req('1a',zgo,zgo1,2)-[_E1,_F1",
#  "req('1b',anj,anj2,3)-[_G1,_H1,_I1",
#  "req('1b',atvz,atvz2,3)-[_J1,_K1,_L1",
#  "req('1b',bio,bio1,2)-[_M1,_N1",
#  "req('1b',fiz,fiz2,2)-[_O1,_P1",
#  "req('1b',geo,geo1,2)-[_Q1,_R1",
#  "req('1b',kem,kem2,2)-[_S1,_4479",
#  "req('1b',mat,mat2,5)-[_4496,_4498,_4500,_4502,_4504",
#  "req('1b',nej,nej2,3)-[_4521,_4523,_4525",
#  "req('1b',rai,rai1,2)-[_4542,_4544",
#  "req('1b',sjk,sjk1,4)-[_4561,_4563,_4565,_4567",
#  "req('1b',ume,ume1,2)-[_4584,_4586",
#  "req('1b',zgo,zgo2,2)-[_4603,_4605",
#  "req('1c',anj,anj3,3)-[_4622,_4624,_4626",
# ...
